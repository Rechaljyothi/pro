# %%
#import required libraries
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score, roc_auc_score, roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
import warnings
warnings.simplefilter(action = "ignore")

# %%
#import the dataset for kaggle
diabetes_dataset= pd.read_csv("C:\\Users\\Jyothi\\Documents\\diabetesdataset.csv")
# The first 10 observation units of the data set were accessed.
diabetes_dataset.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
#display number of columns in a dataset
diabetes_dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [raw]
# # The size of the data set
# diabetes_dataset.shape

# %%
#structure of dats set
diabetes_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
diabetes_dataset.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
#counts number of observations per caterogy(outcome)
sns.countplot(diabetes_dataset['Outcome'])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
#checking no.of diabetes and non diabdetes
diabetes_dataset.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
#find the mean values for diabetes and non diabetes
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#Filling the Missing Values
diabetes_dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#replacing 0 values in column
#filling 0 values in Glucose
diabetes_dataset['Glucose'] = diabetes_dataset['Glucose'].replace(0, diabetes_dataset['Glucose'].median())  
  
# Filling 0 values of Blood Pressure  
diabetes_dataset['BloodPressure'] = diabetes_dataset['BloodPressure'].replace(0, diabetes_dataset['BloodPressure'].median())   
  
# Replacing 0 values in BMI  
diabetes_dataset['BMI'] = diabetes_dataset['BMI'].replace(0, diabetes_dataset['BMI'].mean())  
  
# Replacing the missing values of Insulin and SkinThickness  
diabetes_dataset['SkinThickness'] = diabetes_dataset['SkinThickness'].replace(0, diabetes_dataset['SkinThickness'].mean())  
diabetes_dataset['Insulin'] = diabetes_dataset['Insulin'].replace(0, diabetes_dataset['Insulin'].mean())  
diabetes_dataset.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# 0            6      148             72      35.000000   79.799479  33.600000
# 1            1       85             66      29.000000   79.799479  26.600000
# 2            8      183             64      20.536458   79.799479  23.300000
# 3            1       89             66      23.000000   94.000000  28.100000
# 4            0      137             40      35.000000  168.000000  43.100000
# 5            5      116             74      20.536458   79.799479  25.600000
# 6            3       78             50      32.000000   88.000000  31.000000
# 7           10      115             72      20.536458   79.799479  35.300000
# 8            2      197             70      45.000000  543.000000  30.500000
# 9            8      125             96      20.536458   79.799479  31.992578
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
diabetes_dataset.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128213       0.208615       0.013376
# Glucose                      0.128213  1.000000       0.218937       0.160495
# BloodPressure                0.208615  0.218937       1.000000       0.127874
# SkinThickness                0.013376  0.160495       0.127874       1.000000
# Insulin                     -0.018082  0.397017       0.006385       0.240361
# BMI                          0.021546  0.231408       0.281129       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137327      -0.002378       0.154961
# Age                          0.544341  0.266909       0.324915       0.026423
# Outcome                      0.221898  0.492782       0.165723       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# Glucose                   0.397017  0.231408                  0.137327
# BloodPressure             0.006385  0.281129                 -0.002378
# SkinThickness             0.240361  0.535703                  0.154961
# Insulin                   1.000000  0.189856                  0.157806
# BMI                       0.189856  1.000000                  0.153508
# DiabetesPedigreeFunction  0.157806  0.153508                  1.000000
# Age                       0.038652  0.025748                  0.033561
# Outcome                   0.179185  0.312254                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.266909  0.492782
# BloodPressure             0.324915  0.165723
# SkinThickness             0.026423  0.175026
# Insulin                   0.038652  0.179185
# BMI                       0.025748  0.312254
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
f, ax = plt.subplots(figsize= [20,15])
sns.heatmap(diabetes_dataset.corr(), annot=True, fmt=".2f", ax=ax, cmap = "magma" )
ax.set_title("Correlation Matrix for diabetes dataset", fontsize=20)
plt.show()

# %%
#data distribution for NAN values
p = diabetes_dataset.hist(figsize = (20,20))

# %%
#Histogram and density graph for all columns in a dataset
fig, ax = plt.subplots(4,2, figsize=(16,16))
sns.distplot(diabetes_dataset.Age, bins = 20, ax=ax[0,0]) 
sns.distplot(diabetes_dataset.Pregnancies, bins = 20, ax=ax[0,1]) 
sns.distplot(diabetes_dataset.Glucose, bins = 20, ax=ax[1,0]) 
sns.distplot(diabetes_dataset.BloodPressure, bins = 20, ax=ax[1,1]) 
sns.distplot(diabetes_dataset.SkinThickness, bins = 20, ax=ax[2,0])
sns.distplot(diabetes_dataset.Insulin, bins = 20, ax=ax[2,1])
sns.distplot(diabetes_dataset.DiabetesPedigreeFunction, bins = 20, ax=ax[3,0]) 
sns.distplot(diabetes_dataset.BMI, bins = 20, ax=ax[3,1])
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Density'>
